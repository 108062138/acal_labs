# %%
# !wget https://github.com/onnx/models/raw/main/validated/vision/classification/mobilenet/model/mobilenetv2-10.onnx
# !wget https://github.com/ONNC/onnc-tutorial/raw/master/models/lenet/lenet.onnx

# %%
import onnx
from numpy import nan
from onnx import shape_inference

onnx_model = onnx.load('mobilenetv2-10.onnx')
inferred_model = shape_inference.infer_shapes(onnx_model)
# collect nodes
nodes = {}
for node in onnx_model.graph.node:
    if node.op_type not in nodes:
        nodes[node.op_type] = [node]
    else:
        nodes[node.op_type].append(node)

# %%
print('==================================================================================================================================================')
print('= HW 2-2-1 model characteristics                                                                                                                 =')
print('==================================================================================================================================================')
for type in nodes:
    print('optype: {} : [{}]'.format(type, len(nodes[type])))
# Out:
# ==================================================================================================================================================
# = HW 2-2-1 model characteristics                                                                                                                 =
# ==================================================================================================================================================
# optype: Conv : [52]
# optype: Clip : [35]
# optype: Add : [10]
# optype: GlobalAveragePool : [1]
# optype: Shape : [1]
# optype: Constant : [1]
# optype: Gather : [1]
# optype: Unsqueeze : [1]
# optype: Concat : [1]
# optype: Reshape : [1]
# optype: Gemm : [1]

# %%
res = {}
for type in nodes:
    if type == 'Conv' or type == 'Conv2d':
        for node in nodes[type]:
            key = node.name
            # handle height, width, channel
            dims = []
            for dim in node.input:
                try:
                    dims.append(int(dim))
                except:
                    pass
            if len(dims) == 2:
                dims.append(1)
            height, width, channel = dims[0], dims[1], dims[2]

            kernel_shape, dilations, strides, pads, group = nan, nan, nan, nan, nan

            # handle kernel_shape, dilations, strides
            for attribute in node.attribute:
                if attribute.name == "kernel_shape":
                    kernel_shape = attribute.ints
                elif attribute.name == 'dilations':
                    dilations = attribute.ints
                elif attribute.name == 'strides':
                    strides = attribute.ints
                elif attribute.name == 'pads':
                    pads = attribute.ints
                elif attribute.name == 'group':
                    group = attribute.i
            res[key] = {'height': height, 'width':width, 'channel': channel, 'dilation': dilations, 'stride': strides, 'kernel_size': kernel_shape, 'pads': pads, 'group': group}
    elif type == 'Clip':
        for node in nodes[type]:
            key = node.name
            c_min, c_max = nan, nan
            for attribute in node.attribute:
                if attribute.name == 'min':
                    c_min = attribute.f
                elif attribute.name == 'max':
                    c_max = attribute.f
            res[key] = {'min': c_min, 'max': c_max}
    elif type == 'Add':
        for node in nodes[type]:
            key = node.name
            res[key] = {nan}
    elif type == 'GlobalAveragePool':
        for node in nodes[type]:
            key = node.name
            res[key] = {nan}
    elif type == 'Shape':
        for node in nodes[type]:
            key = node.name
            res[key] = {nan}
    elif type == 'Constant':
        for node in nodes[type]:
            key = node.name
            value = nan
            for attribute in node.attribute:
                if attribute.name == 'value':
                    value = attribute.t
            res[key] = {'value': value}
    elif type == 'Gather':
        for node in nodes[type]:
            key = node.name
            axis = nan
            for attribute in node.attribute:
                if attribute.name == 'axis':
                    axis = attribute.i
            res[key] = {'axis': axis}
    elif type == 'Unsqueeze':
        for node in nodes[type]:
            key = node.name
            axes = nan
            for attribute in node.attribute:
                if attribute.name == 'axes':
                    axes = attribute.ints
            res[key] = {'axes': axes}
    elif type == 'Concat':
        for node in nodes[type]:
            key = node.name
            axis = nan
            for attribute in node.attribute:
                if attribute.name == 'axis':
                    axis = attribute.i
            res[key] = {'axis': axis}
    elif type == 'Reshape':
        for node in nodes[type]:
            key = node.name
            res[key] = {nan}
    elif type == 'Gemm':
        for node in nodes[type]:
            key = node.name
            alpha, beta, transB = nan, nan, nan
            for attribute in node.attribute:
                if attribute.name == 'alpha':
                    alpha = attribute.f
                if attribute.name == 'beta':
                    beta = attribute.f
                if attribute.name == 'transB':
                    transB = attribute.i
            res[key] = {'alpha': alpha, 'beta': beta, 'transB': transB}

# %%
def find_shape_by_name(tensor_name, value_infos):
    for vi in value_infos:
        if vi.name == tensor_name:
            shape = [dim.dim_value for dim in vi.type.tensor_type.shape.dim]
            return shape
    return None
conv_layers_info = []
for node in inferred_model.graph.node:
    if node.op_type == "Conv":
        # Initialize dict to store layer info
        layer_info = {'name': node.name, 'input_shape': [], 'output_shape': []}

        # Input shapes
        for input_name in node.input:
            input_shape = find_shape_by_name(input_name, inferred_model.graph.value_info)
            # In case the shape is not found in value_info, it might be an input tensor
            if input_shape is None:
                input_shape = find_shape_by_name(input_name, inferred_model.graph.input)
            layer_info['input_shape'].append(input_shape)

        # Output shapes
        for output_name in node.output:
            output_shape = find_shape_by_name(output_name, inferred_model.graph.value_info)
            layer_info['output_shape'].append(output_shape)

        conv_layers_info.append(layer_info)
        res[node.name]['input_shape'] = layer_info['input_shape']
        res[node.name]['output_shape'] = layer_info['output_shape']
for k in res:
    print('name: ', k, ' =>', res[k])
# Out:
# name:  Conv_0  => {'height': 475, 'width': 476, 'channel': 1, 'dilation': [1, 1], 'stride': [2, 2], 'kernel_size': [3, 3], 'pads': [1, 1, 1, 1], 'group': 1, 'input_shape': [[0, 3, 224, 224], None, None], 'output_shape': [[0, 32, 112, 112]]}
# name:  Conv_2  => {'height': 317, 'width': 478, 'channel': 479, 'dilation': [1, 1], 'stride': [1, 1], 'kernel_size': [3, 3], 'pads': [1, 1, 1, 1], 'group': 32, 'input_shape': [[0, 32, 112, 112], None, None], 'output_shape': [[0, 32, 112, 112]]}
# name:  Conv_4  => {'height': 320, 'width': 481, 'channel': 482, 'dilation': [1, 1], 'stride': [1, 1], 'kernel_size': [1, 1], 'pads': [0, 0, 0, 0], 'group': 1, 'input_shape': [[0, 32, 112, 112], None, None], 'output_shape': [[0, 16, 112, 112]]}
# name:  Conv_5  => {'height': 480, 'width': 484, 'channel': 485, 'dilation': [1, 1], 'stride': [1, 1], 'kernel_size': [1, 1], 'pads': [0, 0, 0, 0], 'group': 1, 'input_shape': [[0, 16, 112, 112], None, None], 'output_shape': [[0, 96, 112, 112]]}
# name:  Conv_7  => {'height': 325, 'width': 487, 'channel': 488, 'dilation': [1, 1], 'stride': [2, 2], 'kernel_size': [3, 3], 'pads': [1, 1, 1, 1], 'group': 96, 'input_shape': [[0, 96, 112, 112], None, None], 'output_shape': [[0, 96, 56, 56]]}
# name:  Conv_9  => {'height': 328, 'width': 490, 'channel': 491, 'dilation': [1, 1], 'stride': [1, 1], 'kernel_size': [1, 1], 'pads': [0, 0, 0, 0], 'group': 1, 'input_shape': [[0, 96, 56, 56], None, None], 'output_shape': [[0, 24, 56, 56]]}
# name:  Conv_10  => {'height': 489, 'width': 493, 'channel': 494, 'dilation': [1, 1], 'stride': [1, 1], 'kernel_size': [1, 1], 'pads': [0, 0, 0, 0], 'group': 1, 'input_shape': [[0, 24, 56, 56], None, None], 'output_shape': [[0, 144, 56, 56]]}
# name:  Conv_12  => {'height': 333, 'width': 496, 'channel': 497, 'dilation': [1, 1], 'stride': [1, 1], 'kernel_size': [3, 3], 'pads': [1, 1, 1, 1], 'group': 144, 'input_shape': [[0, 144, 56, 56], None, None], 'output_shape': [[0, 144, 56, 56]]}
# name:  Conv_14  => {'height': 336, 'width': 499, 'channel': 500, 'dilation': [1, 1], 'stride': [1, 1], 'kernel_size': [1, 1], 'pads': [0, 0, 0, 0], 'group': 1, 'input_shape': [[0, 144, 56, 56], None, None], 'output_shape': [[0, 24, 56, 56]]}
# name:  Conv_16  => {'height': 339, 'width': 502, 'channel': 503, 'dilation': [1, 1], 'stride': [1, 1], 'kernel_size': [1, 1], 'pads': [0, 0, 0, 0], 'group': 1, 'input_shape': [[0, 24, 56, 56], None, None], 'output_shape': [[0, 144, 56, 56]]}
# name:  Conv_18  => {'height': 342, 'width': 505, 'channel': 506, 'dilation': [1, 1], 'stride': [2, 2], 'kernel_size': [3, 3], 'pads': [1, 1, 1, 1], 'group': 144, 'input_shape': [[0, 144, 56, 56], None, None], 'output_shape': [[0, 144, 28, 28]]}
# name:  Conv_20  => {'height': 345, 'width': 508, 'channel': 509, 'dilation': [1, 1], 'stride': [1, 1], 'kernel_size': [1, 1], 'pads': [0, 0, 0, 0], 'group': 1, 'input_shape': [[0, 144, 28, 28], None, None], 'output_shape': [[0, 32, 28, 28]]}
# name:  Conv_21  => {'height': 507, 'width': 511, 'channel': 512, 'dilation': [1, 1], 'stride': [1, 1], 'kernel_size': [1, 1], 'pads': [0, 0, 0, 0], 'group': 1, 'input_shape': [[0, 32, 28, 28], None, None], 'output_shape': [[0, 192, 28, 28]]}
# name:  Conv_23  => {'height': 350, 'width': 514, 'channel': 515, 'dilation': [1, 1], 'stride': [1, 1], 'kernel_size': [3, 3], 'pads': [1, 1, 1, 1], 'group': 192, 'input_shape': [[0, 192, 28, 28], None, None], 'output_shape': [[0, 192, 28, 28]]}
# name:  Conv_25  => {'height': 353, 'width': 517, 'channel': 518, 'dilation': [1, 1], 'stride': [1, 1], 'kernel_size': [1, 1], 'pads': [0, 0, 0, 0], 'group': 1, 'input_shape': [[0, 192, 28, 28], None, None], 'output_shape': [[0, 32, 28, 28]]}
# name:  Conv_27  => {'height': 356, 'width': 520, 'channel': 521, 'dilation': [1, 1], 'stride': [1, 1], 'kernel_size': [1, 1], 'pads': [0, 0, 0, 0], 'group': 1, 'input_shape': [[0, 32, 28, 28], None, None], 'output_shape': [[0, 192, 28, 28]]}
# name:  Conv_29  => {'height': 359, 'width': 523, 'channel': 524, 'dilation': [1, 1], 'stride': [1, 1], 'kernel_size': [3, 3], 'pads': [1, 1, 1, 1], 'group': 192, 'input_shape': [[0, 192, 28, 28], None, None], 'output_shape': [[0, 192, 28, 28]]}
# name:  Conv_31  => {'height': 362, 'width': 526, 'channel': 527, 'dilation': [1, 1], 'stride': [1, 1], 'kernel_size': [1, 1], 'pads': [0, 0, 0, 0], 'group': 1, 'input_shape': [[0, 192, 28, 28], None, None], 'output_shape': [[0, 32, 28, 28]]}
# name:  Conv_33  => {'height': 365, 'width': 529, 'channel': 530, 'dilation': [1, 1], 'stride': [1, 1], 'kernel_size': [1, 1], 'pads': [0, 0, 0, 0], 'group': 1, 'input_shape': [[0, 32, 28, 28], None, None], 'output_shape': [[0, 192, 28, 28]]}
# name:  Conv_35  => {'height': 368, 'width': 532, 'channel': 533, 'dilation': [1, 1], 'stride': [2, 2], 'kernel_size': [3, 3], 'pads': [1, 1, 1, 1], 'group': 192, 'input_shape': [[0, 192, 28, 28], None, None], 'output_shape': [[0, 192, 14, 14]]}
# name:  Conv_37  => {'height': 371, 'width': 535, 'channel': 536, 'dilation': [1, 1], 'stride': [1, 1], 'kernel_size': [1, 1], 'pads': [0, 0, 0, 0], 'group': 1, 'input_shape': [[0, 192, 14, 14], None, None], 'output_shape': [[0, 64, 14, 14]]}
# name:  Conv_38  => {'height': 534, 'width': 538, 'channel': 539, 'dilation': [1, 1], 'stride': [1, 1], 'kernel_size': [1, 1], 'pads': [0, 0, 0, 0], 'group': 1, 'input_shape': [[0, 64, 14, 14], None, None], 'output_shape': [[0, 384, 14, 14]]}
# name:  Conv_40  => {'height': 376, 'width': 541, 'channel': 542, 'dilation': [1, 1], 'stride': [1, 1], 'kernel_size': [3, 3], 'pads': [1, 1, 1, 1], 'group': 384, 'input_shape': [[0, 384, 14, 14], None, None], 'output_shape': [[0, 384, 14, 14]]}
# name:  Conv_42  => {'height': 379, 'width': 544, 'channel': 545, 'dilation': [1, 1], 'stride': [1, 1], 'kernel_size': [1, 1], 'pads': [0, 0, 0, 0], 'group': 1, 'input_shape': [[0, 384, 14, 14], None, None], 'output_shape': [[0, 64, 14, 14]]}
# name:  Conv_44  => {'height': 382, 'width': 547, 'channel': 548, 'dilation': [1, 1], 'stride': [1, 1], 'kernel_size': [1, 1], 'pads': [0, 0, 0, 0], 'group': 1, 'input_shape': [[0, 64, 14, 14], None, None], 'output_shape': [[0, 384, 14, 14]]}
# name:  Conv_46  => {'height': 385, 'width': 550, 'channel': 551, 'dilation': [1, 1], 'stride': [1, 1], 'kernel_size': [3, 3], 'pads': [1, 1, 1, 1], 'group': 384, 'input_shape': [[0, 384, 14, 14], None, None], 'output_shape': [[0, 384, 14, 14]]}
# name:  Conv_48  => {'height': 388, 'width': 553, 'channel': 554, 'dilation': [1, 1], 'stride': [1, 1], 'kernel_size': [1, 1], 'pads': [0, 0, 0, 0], 'group': 1, 'input_shape': [[0, 384, 14, 14], None, None], 'output_shape': [[0, 64, 14, 14]]}
# name:  Conv_50  => {'height': 391, 'width': 556, 'channel': 557, 'dilation': [1, 1], 'stride': [1, 1], 'kernel_size': [1, 1], 'pads': [0, 0, 0, 0], 'group': 1, 'input_shape': [[0, 64, 14, 14], None, None], 'output_shape': [[0, 384, 14, 14]]}
# name:  Conv_52  => {'height': 394, 'width': 559, 'channel': 560, 'dilation': [1, 1], 'stride': [1, 1], 'kernel_size': [3, 3], 'pads': [1, 1, 1, 1], 'group': 384, 'input_shape': [[0, 384, 14, 14], None, None], 'output_shape': [[0, 384, 14, 14]]}
# name:  Conv_54  => {'height': 397, 'width': 562, 'channel': 563, 'dilation': [1, 1], 'stride': [1, 1], 'kernel_size': [1, 1], 'pads': [0, 0, 0, 0], 'group': 1, 'input_shape': [[0, 384, 14, 14], None, None], 'output_shape': [[0, 64, 14, 14]]}
# name:  Conv_56  => {'height': 400, 'width': 565, 'channel': 566, 'dilation': [1, 1], 'stride': [1, 1], 'kernel_size': [1, 1], 'pads': [0, 0, 0, 0], 'group': 1, 'input_shape': [[0, 64, 14, 14], None, None], 'output_shape': [[0, 384, 14, 14]]}
# name:  Conv_58  => {'height': 403, 'width': 568, 'channel': 569, 'dilation': [1, 1], 'stride': [1, 1], 'kernel_size': [3, 3], 'pads': [1, 1, 1, 1], 'group': 384, 'input_shape': [[0, 384, 14, 14], None, None], 'output_shape': [[0, 384, 14, 14]]}
# name:  Conv_60  => {'height': 406, 'width': 571, 'channel': 572, 'dilation': [1, 1], 'stride': [1, 1], 'kernel_size': [1, 1], 'pads': [0, 0, 0, 0], 'group': 1, 'input_shape': [[0, 384, 14, 14], None, None], 'output_shape': [[0, 96, 14, 14]]}
# name:  Conv_61  => {'height': 570, 'width': 574, 'channel': 575, 'dilation': [1, 1], 'stride': [1, 1], 'kernel_size': [1, 1], 'pads': [0, 0, 0, 0], 'group': 1, 'input_shape': [[0, 96, 14, 14], None, None], 'output_shape': [[0, 576, 14, 14]]}
# name:  Conv_63  => {'height': 411, 'width': 577, 'channel': 578, 'dilation': [1, 1], 'stride': [1, 1], 'kernel_size': [3, 3], 'pads': [1, 1, 1, 1], 'group': 576, 'input_shape': [[0, 576, 14, 14], None, None], 'output_shape': [[0, 576, 14, 14]]}
# name:  Conv_65  => {'height': 414, 'width': 580, 'channel': 581, 'dilation': [1, 1], 'stride': [1, 1], 'kernel_size': [1, 1], 'pads': [0, 0, 0, 0], 'group': 1, 'input_shape': [[0, 576, 14, 14], None, None], 'output_shape': [[0, 96, 14, 14]]}
# name:  Conv_67  => {'height': 417, 'width': 583, 'channel': 584, 'dilation': [1, 1], 'stride': [1, 1], 'kernel_size': [1, 1], 'pads': [0, 0, 0, 0], 'group': 1, 'input_shape': [[0, 96, 14, 14], None, None], 'output_shape': [[0, 576, 14, 14]]}
# name:  Conv_69  => {'height': 420, 'width': 586, 'channel': 587, 'dilation': [1, 1], 'stride': [1, 1], 'kernel_size': [3, 3], 'pads': [1, 1, 1, 1], 'group': 576, 'input_shape': [[0, 576, 14, 14], None, None], 'output_shape': [[0, 576, 14, 14]]}
# name:  Conv_71  => {'height': 423, 'width': 589, 'channel': 590, 'dilation': [1, 1], 'stride': [1, 1], 'kernel_size': [1, 1], 'pads': [0, 0, 0, 0], 'group': 1, 'input_shape': [[0, 576, 14, 14], None, None], 'output_shape': [[0, 96, 14, 14]]}
# name:  Conv_73  => {'height': 426, 'width': 592, 'channel': 593, 'dilation': [1, 1], 'stride': [1, 1], 'kernel_size': [1, 1], 'pads': [0, 0, 0, 0], 'group': 1, 'input_shape': [[0, 96, 14, 14], None, None], 'output_shape': [[0, 576, 14, 14]]}
# name:  Conv_75  => {'height': 429, 'width': 595, 'channel': 596, 'dilation': [1, 1], 'stride': [2, 2], 'kernel_size': [3, 3], 'pads': [1, 1, 1, 1], 'group': 576, 'input_shape': [[0, 576, 14, 14], None, None], 'output_shape': [[0, 576, 7, 7]]}
# name:  Conv_77  => {'height': 432, 'width': 598, 'channel': 599, 'dilation': [1, 1], 'stride': [1, 1], 'kernel_size': [1, 1], 'pads': [0, 0, 0, 0], 'group': 1, 'input_shape': [[0, 576, 7, 7], None, None], 'output_shape': [[0, 160, 7, 7]]}
# name:  Conv_78  => {'height': 597, 'width': 601, 'channel': 602, 'dilation': [1, 1], 'stride': [1, 1], 'kernel_size': [1, 1], 'pads': [0, 0, 0, 0], 'group': 1, 'input_shape': [[0, 160, 7, 7], None, None], 'output_shape': [[0, 960, 7, 7]]}
# name:  Conv_80  => {'height': 437, 'width': 604, 'channel': 605, 'dilation': [1, 1], 'stride': [1, 1], 'kernel_size': [3, 3], 'pads': [1, 1, 1, 1], 'group': 960, 'input_shape': [[0, 960, 7, 7], None, None], 'output_shape': [[0, 960, 7, 7]]}
# name:  Conv_82  => {'height': 440, 'width': 607, 'channel': 608, 'dilation': [1, 1], 'stride': [1, 1], 'kernel_size': [1, 1], 'pads': [0, 0, 0, 0], 'group': 1, 'input_shape': [[0, 960, 7, 7], None, None], 'output_shape': [[0, 160, 7, 7]]}
# name:  Conv_84  => {'height': 443, 'width': 610, 'channel': 611, 'dilation': [1, 1], 'stride': [1, 1], 'kernel_size': [1, 1], 'pads': [0, 0, 0, 0], 'group': 1, 'input_shape': [[0, 160, 7, 7], None, None], 'output_shape': [[0, 960, 7, 7]]}
# name:  Conv_86  => {'height': 446, 'width': 613, 'channel': 614, 'dilation': [1, 1], 'stride': [1, 1], 'kernel_size': [3, 3], 'pads': [1, 1, 1, 1], 'group': 960, 'input_shape': [[0, 960, 7, 7], None, None], 'output_shape': [[0, 960, 7, 7]]}
# name:  Conv_88  => {'height': 449, 'width': 616, 'channel': 617, 'dilation': [1, 1], 'stride': [1, 1], 'kernel_size': [1, 1], 'pads': [0, 0, 0, 0], 'group': 1, 'input_shape': [[0, 960, 7, 7], None, None], 'output_shape': [[0, 160, 7, 7]]}
# name:  Conv_90  => {'height': 452, 'width': 619, 'channel': 620, 'dilation': [1, 1], 'stride': [1, 1], 'kernel_size': [1, 1], 'pads': [0, 0, 0, 0], 'group': 1, 'input_shape': [[0, 160, 7, 7], None, None], 'output_shape': [[0, 960, 7, 7]]}
# name:  Conv_92  => {'height': 455, 'width': 622, 'channel': 623, 'dilation': [1, 1], 'stride': [1, 1], 'kernel_size': [3, 3], 'pads': [1, 1, 1, 1], 'group': 960, 'input_shape': [[0, 960, 7, 7], None, None], 'output_shape': [[0, 960, 7, 7]]}
# name:  Conv_94  => {'height': 458, 'width': 625, 'channel': 626, 'dilation': [1, 1], 'stride': [1, 1], 'kernel_size': [1, 1], 'pads': [0, 0, 0, 0], 'group': 1, 'input_shape': [[0, 960, 7, 7], None, None], 'output_shape': [[0, 320, 7, 7]]}
# name:  Conv_95  => {'height': 624, 'width': 628, 'channel': 629, 'dilation': [1, 1], 'stride': [1, 1], 'kernel_size': [1, 1], 'pads': [0, 0, 0, 0], 'group': 1, 'input_shape': [[0, 320, 7, 7], None, None], 'output_shape': [[0, 1280, 7, 7]]}
# name:  Clip_1  => {'min': 0.0, 'max': 6.0}
# name:  Clip_3  => {'min': 0.0, 'max': 6.0}
# name:  Clip_6  => {'min': 0.0, 'max': 6.0}
# name:  Clip_8  => {'min': 0.0, 'max': 6.0}
# name:  Clip_11  => {'min': 0.0, 'max': 6.0}
# name:  Clip_13  => {'min': 0.0, 'max': 6.0}
# name:  Clip_17  => {'min': 0.0, 'max': 6.0}
# name:  Clip_19  => {'min': 0.0, 'max': 6.0}
# name:  Clip_22  => {'min': 0.0, 'max': 6.0}
# name:  Clip_24  => {'min': 0.0, 'max': 6.0}
# name:  Clip_28  => {'min': 0.0, 'max': 6.0}
# name:  Clip_30  => {'min': 0.0, 'max': 6.0}
# name:  Clip_34  => {'min': 0.0, 'max': 6.0}
# name:  Clip_36  => {'min': 0.0, 'max': 6.0}
# name:  Clip_39  => {'min': 0.0, 'max': 6.0}
# name:  Clip_41  => {'min': 0.0, 'max': 6.0}
# name:  Clip_45  => {'min': 0.0, 'max': 6.0}
# name:  Clip_47  => {'min': 0.0, 'max': 6.0}
# name:  Clip_51  => {'min': 0.0, 'max': 6.0}
# name:  Clip_53  => {'min': 0.0, 'max': 6.0}
# name:  Clip_57  => {'min': 0.0, 'max': 6.0}
# name:  Clip_59  => {'min': 0.0, 'max': 6.0}
# name:  Clip_62  => {'min': 0.0, 'max': 6.0}
# name:  Clip_64  => {'min': 0.0, 'max': 6.0}
# name:  Clip_68  => {'min': 0.0, 'max': 6.0}
# name:  Clip_70  => {'min': 0.0, 'max': 6.0}
# name:  Clip_74  => {'min': 0.0, 'max': 6.0}
# name:  Clip_76  => {'min': 0.0, 'max': 6.0}
# name:  Clip_79  => {'min': 0.0, 'max': 6.0}
# name:  Clip_81  => {'min': 0.0, 'max': 6.0}
# name:  Clip_85  => {'min': 0.0, 'max': 6.0}
# name:  Clip_87  => {'min': 0.0, 'max': 6.0}
# name:  Clip_91  => {'min': 0.0, 'max': 6.0}
# name:  Clip_93  => {'min': 0.0, 'max': 6.0}
# name:  Clip_96  => {'min': 0.0, 'max': 6.0}
# name:  Add_15  => {nan}
# name:  Add_26  => {nan}
# name:  Add_32  => {nan}
# name:  Add_43  => {nan}
# name:  Add_49  => {nan}
# name:  Add_55  => {nan}
# name:  Add_66  => {nan}
# name:  Add_72  => {nan}
# name:  Add_83  => {nan}
# name:  Add_89  => {nan}
# name:  GlobalAveragePool_97  => {nan}
# name:  Shape_98  => {nan}
# name:  Constant_99  => {'value': data_type: 7
# raw_data: "\000\000\000\000\000\000\000\000"
# }
# name:  Gather_100  => {'axis': 0}
# name:  Unsqueeze_101  => {'axes': [0]}
# name:  Concat_102  => {'axis': 0}
# name:  Reshape_103  => {nan}
# name:  Gemm_104  => {'alpha': 1.0, 'beta': 1.0, 'transB': 1}

# %%
from onnx import shape_inference
inferred_model = shape_inference.infer_shapes(onnx_model)

import onnx
from onnx import shape_inference
from os import path
import sys
from tabulate import tabulate
from onnx import onnx_ml_pb2 as xpb2


onnx_model = onnx.load("mobilenetv2-10.onnx", load_external_data=False)
onnx.checker.check_model(onnx_model)

inferred_model = shape_inference.infer_shapes(onnx_model)
print('shape inference complete ...')

def _parse_element(elem: xpb2.ValueInfoProto):
    name = getattr(elem, 'name', "None")
    data_type = "NA"
    shape_str = "NA"
    etype = getattr(elem, 'type', False)
    if etype:
        ttype = getattr(etype, 'tensor_type', False)
        if ttype:
            data_type = getattr(ttype, 'elem_type', 0)
            shape = getattr(elem.type.tensor_type, "shape", False)
            if shape:
                shape_str = "["
                dims = getattr(shape, 'dim', [])
                for dim in dims:
                    vals = getattr(dim, 'dim_value', "?")
                    shape_str += (str(vals) + ",")
                shape_str = shape_str.rstrip(",")
                shape_str += "]"
    return name, data_type, shape_str

def get_valueproto_or_tensorproto_by_name(name: str, graph: xpb2.GraphProto):
    for i, node in enumerate(inferred_model.graph.node):
            if node.name == "":
                inferred_model.graph.node[i].name = str(i)
    input_nlist = [k.name for k in graph.input]
    initializer_nlist = [k.name for k in graph.initializer]
    value_info_nlist = [k.name for k in graph.value_info]
    output_nlist = [k.name for k in graph.output]

    # get tensor data
    if name in input_nlist:
        idx = input_nlist.index(name)
        return graph.input[idx], int(1)
    elif name in value_info_nlist:
        idx = value_info_nlist.index(name)
        return graph.value_info[idx], int(2)
    elif name in initializer_nlist:
        idx = initializer_nlist.index(name)
        return graph.initializer[idx], int(3)
    elif name in output_nlist:
        idx = output_nlist.index(name)
        return graph.output[idx], int(4)
    else:
        print("[ERROR MASSAGE] Can't find the tensor: ", name)
        print('input_nlist:\n', input_nlist)
        print('===================')
        print('value_info_nlist:\n', value_info_nlist)
        print('===================')
        print('initializer_nlist:\n', initializer_nlist)
        print('===================')
        print('output_nlist:\n', output_nlist)
        print('===================')
        return False, 0

def cal_tensor_mem_size(elem_type: str, shape: [int]):
    """ given the element type of the tensor and its shape, and return its memory size.

    Utility.

    Args:
        ttype: the type of the element of the given tensor. format: 'int', ...
        shape: the shape of the given tensor. format: [] of int

    Returns:
        mem_size: int
    """
    # init
    mem_size = int(1)
    # traverse the list to get the number of the elements
    for num in shape:
        mem_size *= num
    # multiple the size of variable with the number of the elements
    # "FLOAT": 1,
    # "UINT8": 2,
    # "INT8": 3,
    # "UINT16": 4,
    # "INT16": 5,
    # "INT32": 6,
    # "INT64": 7,
    # # "STRING" : 8,
    # "BOOL": 9,
    # "FLOAT16": 10,
    # "DOUBLE": 11,
    # "UINT32": 12,
    # "UINT64": 13,
    # "COMPLEX64": 14,
    # "COMPLEX128": 15
    if elem_type == 1:
        mem_size *= 4
    elif elem_type == 2:
        mem_size *= 1
    elif elem_type == 3:
        mem_size *= 1
    elif elem_type == 4:
        mem_size *= 2
    elif elem_type == 5:
        mem_size *= 2
    elif elem_type == 6:
        mem_size *= 4
    elif elem_type == 7:
        mem_size *= 8
    elif elem_type == 9:
        mem_size *= 1
    elif elem_type == 10:
        mem_size *= 2
    elif elem_type == 11:
        mem_size *= 8
    elif elem_type == 12:
        mem_size *= 4
    elif elem_type == 13:
        mem_size *= 8
    elif elem_type == 14:
        mem_size *= 8
    elif elem_type == 15:
        mem_size *= 16
    else:
        print("Undefined data type")

    return mem_size



def get_bandwidth(graph: xpb2.GraphProto):
    try:
        mem_BW_list = []
        total_mem_BW = 0
        unknown_tensor_list = []
        # traverse all the nodes
        for nodeProto in graph.node:
            # init variables
            read_mem_BW_each_layer = 0
            write_mem_BW_each_layer = 0
            total_each_layer = 0
            # traverse all input tensor
            for input_name in nodeProto.input:
                # get the TensorProto/ValueInfoProto by searching its name
                proto, type_Num = get_valueproto_or_tensorproto_by_name(
                    input_name, graph)
                # parse the ValueInfoProto/TensorProto
                if proto:
                    if type_Num == 3:
                        dtype = getattr(proto, 'data_type', False)
                        # get the shape of the tensor
                        shape = getattr(proto, 'dims', [])
                    elif type_Num == 1 or type_Num == 2:
                        name, dtype, shape_str = _parse_element(proto)
                        shape_str = shape_str.strip('[]')
                        shape_str = shape_str.split(',')
                        shape = []
                        for dim in shape_str:
                            if dim != '':
                                shape.append(int(dim))
                    else:
                        print(
                            '[ERROR MASSAGE] [get_info/mem_BW_without_buf] The Tensor: ',
                            input_name, ' is from a wrong list !')
                else:
                    print(
                        '[ERROR MASSAGE] [get_info/mem_BW_without_buf] The Tensor: ',
                        input_name, ' is no found !')
                    unknown_tensor_list.append(
                        (nodeProto.name, input_name, nodeProto.op_type))
                # calculate the tensor size in btye
                
                read_mem_BW_each_layer += cal_tensor_mem_size(dtype, shape)

            # traverse all output tensor
            for output_name in nodeProto.output:
                # get the TensorProto/ValueInfoProto by searching its name
                proto, type_Num = get_valueproto_or_tensorproto_by_name(
                    output_name, graph)
                # parse the ValueInfoProto
                if proto:
                    if type_Num == 2 or type_Num == 4:
                        # name, dtype, shape = utils._parse_ValueInfoProto(proto)
                        name, dtype, shape_str = _parse_element(proto)
                        shape_str = shape_str.strip('[]')
                        shape_str = shape_str.split(',')
                        shape = []
                        for dim in shape_str:
                            if dim != '':
                                shape.append(int(dim))
                    else:
                        print(
                            '[ERROR MASSAGE] [get_info/mem_BW_without_buf] The Tensor: ',
                            output_name, ' is from a wrong list !')
                else:
                    print(
                        '[ERROR MASSAGE] [get_info/mem_BW_without_buf] The Tensor: ',
                        input_name, ' is no found !')
                    unknown_tensor_list.append(
                        (nodeProto.name, output_name, nodeProto.op_type))
                # calculate the tensor size in btye
                write_mem_BW_each_layer += cal_tensor_mem_size(dtype, shape)

            # cal total bw
            total_each_layer = read_mem_BW_each_layer + write_mem_BW_each_layer

            # store into tuple
            temp_tuple = (nodeProto.name, read_mem_BW_each_layer,
                        write_mem_BW_each_layer, total_each_layer)
            #append it
            mem_BW_list.append(temp_tuple)
            # accmulate the value
            total_mem_BW += total_each_layer

        # display the mem_bw of eahc layer
        columns = ['layer', 'read_bw', 'write_bw', 'total_bw']
        # resort the list
        mem_BW_list = sorted(mem_BW_list,
                             key=lambda Layer: Layer[1],
                             reverse=True)
        print(tabulate(mem_BW_list, headers=columns))
        print(
            '====================================================================================\n'
        )
        # display it
        print(
            "The memory bandwidth for processor to execute a whole model without on-chip-buffer is: \n",
            total_mem_BW, '(bytes)\n',
            float(total_mem_BW) / float(1000000), '(MB)\n')
        # display the unknown tensor
        columns = ['op_name', 'unfound_tensor', 'op_type']
        print(tabulate(unknown_tensor_list, headers=columns))
        print(
            '====================================================================================\n'
        )
    except Exception as e:
        print("[ERROR MASSAGE] Unable to display: " + str(e))
        return False

    return True

#從這裡開始
print("start")
print('==================================================================================================================================================')
print('= HW 2-2-2 Data bandwidth requirement                                                                                                            =')
print('==================================================================================================================================================')
get_bandwidth(inferred_model.graph)
# Out:
# shape inference complete ...
# start
# ==================================================================================================================================================
# = HW 2-2-2 Data bandwidth requirement                                                                                                            =
# ==================================================================================================================================================
# layer                   read_bw    write_bw    total_bw
# --------------------  ---------  ----------  ----------
# Gemm_104                5124004           0     5124004
# Conv_95                 1643520           0     1643520
# Conv_94                 1230080           0     1230080
# Conv_78                  618240           0      618240
# Conv_84                  618240           0      618240
# Conv_90                  618240           0      618240
# Conv_82                  615040           0      615040
# Conv_88                  615040           0      615040
# Conv_77                  369280           0      369280
# Conv_61                  223488           0      223488
# Conv_67                  223488           0      223488
# Conv_73                  223488           0      223488
# Conv_65                  221568           0      221568
# Conv_71                  221568           0      221568
# Conv_60                  147840           0      147840
# Conv_38                   99840           0       99840
# Conv_44                   99840           0       99840
# Conv_50                   99840           0       99840
# Conv_56                   99840           0       99840
# Conv_42                   98560           0       98560
# Conv_48                   98560           0       98560
# Conv_54                   98560           0       98560
# Conv_37                   49408           0       49408
# Conv_80                   38400           0       38400
# Conv_86                   38400           0       38400
# Conv_92                   38400           0       38400
# Conv_21                   25344           0       25344
# Conv_27                   25344           0       25344
# Conv_33                   25344           0       25344
# Conv_25                   24704           0       24704
# Conv_31                   24704           0       24704
# Conv_63                   23040           0       23040
# Conv_69                   23040           0       23040
# Conv_75                   23040           0       23040
# Conv_20                   18560           0       18560
# Conv_40                   15360           0       15360
# Conv_46                   15360           0       15360
# Conv_52                   15360           0       15360
# Conv_58                   15360           0       15360
# Conv_10                   14400           0       14400
# Conv_16                   14400           0       14400
# Conv_14                   13920           0       13920
# Conv_9                     9312           0        9312
# Conv_23                    7680           0        7680
# Conv_29                    7680           0        7680
# Conv_35                    7680           0        7680
# Conv_5                     6528           0        6528
# Conv_12                    5760           0        5760
# Conv_18                    5760           0        5760
# Conv_7                     3840           0        3840
# Conv_0                     3584           0        3584
# Conv_4                     2112           0        2112
# Conv_2                     1280           0        1280
# Gather_100                   40           8          48
# Concat_102                   16          16          32
# Reshape_103                  16           4          20
# Unsqueeze_101                 8           8          16
# Clip_1                        0           0           0
# Clip_3                        0           0           0
# Clip_6                        0           0           0
# Clip_8                        0           0           0
# Clip_11                       0           0           0
# Clip_13                       0           0           0
# Add_15                        0           0           0
# Clip_17                       0           0           0
# Clip_19                       0           0           0
# Clip_22                       0           0           0
# Clip_24                       0           0           0
# Add_26                        0           0           0
# Clip_28                       0           0           0
# Clip_30                       0           0           0
# Add_32                        0           0           0
# Clip_34                       0           0           0
# Clip_36                       0           0           0
# Clip_39                       0           0           0
# Clip_41                       0           0           0
# Add_43                        0           0           0
# Clip_45                       0           0           0
# Clip_47                       0           0           0
# Add_49                        0           0           0
# Clip_51                       0           0           0
# Clip_53                       0           0           0
# Add_55                        0           0           0
# Clip_57                       0           0           0
# Clip_59                       0           0           0
# Clip_62                       0           0           0
# Clip_64                       0           0           0
# Add_66                        0           0           0
# Clip_68                       0           0           0
# Clip_70                       0           0           0
# Add_72                        0           0           0
# Clip_74                       0           0           0
# Clip_76                       0           0           0
# Clip_79                       0           0           0
# Clip_81                       0           0           0
# Add_83                        0           0           0
# Clip_85                       0           0           0
# Clip_87                       0           0           0
# Add_89                        0           0           0
# Clip_91                       0           0           0
# Clip_93                       0           0           0
# Clip_96                       0           0           0
# GlobalAveragePool_97          0           0           0
# Shape_98                      0          32          32
# Constant_99                   0           8           8
# ====================================================================================
#
# The memory bandwidth for processor to execute a whole model without on-chip-buffer is:
#  13951424 (bytes)
#  13.951424 (MB)
#
# op_name    unfound_tensor    op_type
# ---------  ----------------  ---------
# ====================================================================================
# True

# %%
total_mem = 0
for key in res:
    if 'Conv' in key:
        #print(key)
        output_dims = res[key]['output_shape'][0]
        psum = 1
        for dim in output_dims:
            if dim != 0:
                psum *= dim
        total_mem += psum
print('==================================================================================================================================================')
print('= HW 2-2-3 activation memory storage requirement                                                                                                 =')
print('==================================================================================================================================================')
print( 'residual memory requeriment: {} (MB)'.format(total_mem * 4 / 1024 / 1024))
# Out:
# ==================================================================================================================================================
# = HW 2-2-3 activation memory storage requirement                                                                                                 =
# ==================================================================================================================================================
# residual memory requeriment: 25.4749755859375 (MB)
